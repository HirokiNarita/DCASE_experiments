# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm
import torch_optimizer
#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from pytorch_model import EfficientNet_b1 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %%
#model = timm.create_model('efficientnet_b1', pretrained=True)
#3, 320, 320
#name: (channel_multiplier, depth_multiplier, resolution, dropout_rate)
#(1.4, 1.8, 380, 0.4)

# %%
#model.blocks[0][0]

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/DCASE_experiments/SSL-Efficientnet_Barlow_Twins_mixup_0.4_batchnorm/dcase2021_task2/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # source mode
    dev_train_paths = dev_train_source_paths + dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(dev_train_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # source mode
    add_dev_paths = add_dev_source_paths + add_dev_target_paths
    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3026, source_size : 3105, target_size : 9
# ==============================================================
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['fan', 'gearbox', 'pump', 'slider', 'ToyCar', 'ToyTrain', 'valve']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('FEATURE EXTRACTION')
    net = Model(n_out=config['param']['mel_bins'])
    optimizer = torch_optimizer.RAdam(net.parameters())
    #scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.001, steps_per_epoch=len(dataloaders_dict['train']), epochs=config['param']['num_epochs'])
    output_dicts = modeler.train_net(net, dataloaders_dict, writer, optimizer)
    
    out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    torch.save(output_dicts['net'], out_path)
    logger.info(f'SAVE SUCCESS : {out_path}')
    
    com.toc()

# %% [markdown]
# # run

# %%
for machine_type in machine_types[1:]:
    run(machine_type, dev_paths)
# Out:
# 2021-08-13 00:33:11,817 - 00_train.py - INFO - TARGET MACHINE_TYPE: fan
# 2021-08-13 00:33:11,818 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-08-13 00:33:11,819 - 00_train.py - INFO - FEATURE EXTRACTION
# use: cuda:0
# 100%|██████████| 24/24 [00:26<00:00,  1.10s/it]
# 2021-08-13 00:33:41,508 - pytorch_modeler.py - INFO - epoch:1/200, tr_loss:29727.154663
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 2021-08-13 00:34:07,247 - pytorch_modeler.py - INFO - epoch:2/200, tr_loss:27677.731812
# 100%|██████████| 24/24 [00:26<00:00,  1.11s/it]
# 2021-08-13 00:34:33,998 - pytorch_modeler.py - INFO - epoch:3/200, tr_loss:24074.543152
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 2021-08-13 00:34:59,605 - pytorch_modeler.py - INFO - epoch:4/200, tr_loss:22324.161255
# 100%|██████████| 24/24 [00:24<00:00,  1.02s/it]
# 2021-08-13 00:35:24,130 - pytorch_modeler.py - INFO - epoch:5/200, tr_loss:21550.982971
# 100%|██████████| 24/24 [00:25<00:00,  1.08s/it]
# 2021-08-13 00:35:50,104 - pytorch_modeler.py - INFO - epoch:6/200, tr_loss:21117.010254
# 100%|██████████| 24/24 [00:26<00:00,  1.11s/it]
# 2021-08-13 00:36:16,820 - pytorch_modeler.py - INFO - epoch:7/200, tr_loss:19918.026489
# 100%|██████████| 24/24 [00:25<00:00,  1.04s/it]
# 2021-08-13 00:36:41,829 - pytorch_modeler.py - INFO - epoch:8/200, tr_loss:18506.532898
# 100%|██████████| 24/24 [00:25<00:00,  1.06s/it]
# 2021-08-13 00:37:07,325 - pytorch_modeler.py - INFO - epoch:9/200, tr_loss:17865.354553
# 100%|██████████| 24/24 [00:23<00:00,  1.00it/s]
# 2021-08-13 00:37:31,281 - pytorch_modeler.py - INFO - epoch:10/200, tr_loss:17238.839783
# 100%|██████████| 24/24 [00:26<00:00,  1.10s/it]
# 2021-08-13 00:37:57,629 - pytorch_modeler.py - INFO - epoch:11/200, tr_loss:16685.240417
# 100%|██████████| 24/24 [00:26<00:00,  1.09s/it]
# 2021-08-13 00:38:23,782 - pytorch_modeler.py - INFO - epoch:12/200, tr_loss:15889.003174
# 100%|██████████| 24/24 [00:27<00:00,  1.13s/it]
# 2021-08-13 00:38:50,935 - pytorch_modeler.py - INFO - epoch:13/200, tr_loss:15081.210999
# 100%|██████████| 24/24 [00:26<00:00,  1.11s/it]
# 2021-08-13 00:39:17,656 - pytorch_modeler.py - INFO - epoch:14/200, tr_loss:14389.667847
# 100%|██████████| 24/24 [00:26<00:00,  1.11s/it]
# 2021-08-13 00:39:44,388 - pytorch_modeler.py - INFO - epoch:15/200, tr_loss:13678.023438
# 100%|██████████| 24/24 [00:26<00:00,  1.12s/it]
# 2021-08-13 00:40:11,189 - pytorch_modeler.py - INFO - epoch:16/200, tr_loss:13463.880493
# 100%|██████████| 24/24 [00:26<00:00,  1.11s/it]
# 2021-08-13 00:40:37,847 - pytorch_modeler.py - INFO - epoch:17/200, tr_loss:12689.829956
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 2021-08-13 00:41:03,529 - pytorch_modeler.py - INFO - epoch:18/200, tr_loss:12103.455292
# 100%|██████████| 24/24 [00:26<00:00,  1.10s/it]
# 2021-08-13 00:41:29,884 - pytorch_modeler.py - INFO - epoch:19/200, tr_loss:11737.386810
# 100%|██████████| 24/24 [00:25<00:00,  1.06s/it]
# 2021-08-13 00:41:55,413 - pytorch_modeler.py - INFO - epoch:20/200, tr_loss:11040.480408
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 2021-08-13 00:42:21,041 - pytorch_modeler.py - INFO - epoch:21/200, tr_loss:10827.367950
# 100%|██████████| 24/24 [00:26<00:00,  1.10s/it]
# 2021-08-13 00:42:47,371 - pytorch_modeler.py - INFO - epoch:22/200, tr_loss:10382.924988
# 100%|██████████| 24/24 [00:26<00:00,  1.10s/it]
# 2021-08-13 00:43:13,864 - pytorch_modeler.py - INFO - epoch:23/200, tr_loss:10240.015625
# 100%|██████████| 24/24 [00:24<00:00,  1.02s/it]
# 2021-08-13 00:43:38,465 - pytorch_modeler.py - INFO - epoch:24/200, tr_loss:9986.854401
# 100%|██████████| 24/24 [00:27<00:00,  1.16s/it]
# 2021-08-13 00:44:06,327 - pytorch_modeler.py - INFO - epoch:25/200, tr_loss:9646.030579
# 100%|██████████| 24/24 [00:27<00:00,  1.16s/it]
# 2021-08-13 00:44:34,177 - pytorch_modeler.py - INFO - epoch:26/200, tr_loss:9581.143738
# 100%|██████████| 24/24 [00:25<00:00,  1.08s/it]
# 2021-08-13 00:45:00,121 - pytorch_modeler.py - INFO - epoch:27/200, tr_loss:9358.650909
# 100%|██████████| 24/24 [00:25<00:00,  1.08s/it]
# 2021-08-13 00:45:26,006 - pytorch_modeler.py - INFO - epoch:28/200, tr_loss:9032.352570
# 100%|██████████| 24/24 [00:26<00:00,  1.08s/it]
# 2021-08-13 00:45:52,015 - pytorch_modeler.py - INFO - epoch:29/200, tr_loss:8979.554901
# 100%|██████████| 24/24 [00:26<00:00,  1.12s/it]
# 2021-08-13 00:46:18,997 - pytorch_modeler.py - INFO - epoch:30/200, tr_loss:8774.229523
# 100%|██████████| 24/24 [00:26<00:00,  1.09s/it]
# 2021-08-13 00:46:45,152 - pytorch_modeler.py - INFO - epoch:31/200, tr_loss:8654.174133
# 100%|██████████| 24/24 [00:25<00:00,  1.08s/it]
# 2021-08-13 00:47:11,081 - pytorch_modeler.py - INFO - epoch:32/200, tr_loss:8455.164307
# 100%|██████████| 24/24 [00:26<00:00,  1.11s/it]
# 2021-08-13 00:47:37,753 - pytorch_modeler.py - INFO - epoch:33/200, tr_loss:8283.442566
# 100%|██████████| 24/24 [00:28<00:00,  1.17s/it]
# 2021-08-13 00:48:05,937 - pytorch_modeler.py - INFO - epoch:34/200, tr_loss:8061.043213
# 100%|██████████| 24/24 [00:24<00:00,  1.03s/it]
# 2021-08-13 00:48:30,776 - pytorch_modeler.py - INFO - epoch:35/200, tr_loss:7964.576874
# 100%|██████████| 24/24 [00:24<00:00,  1.00s/it]
# 2021-08-13 00:48:54,786 - pytorch_modeler.py - INFO - epoch:36/200, tr_loss:7938.758331
# 100%|██████████| 24/24 [00:23<00:00,  1.01it/s]
# 2021-08-13 00:49:18,671 - pytorch_modeler.py - INFO - epoch:37/200, tr_loss:7896.571716
# 100%|██████████| 24/24 [00:24<00:00,  1.03s/it]
# 2021-08-13 00:49:43,450 - pytorch_modeler.py - INFO - epoch:38/200, tr_loss:7663.312714
# 100%|██████████| 24/24 [00:27<00:00,  1.13s/it]
# 2021-08-13 00:50:10,455 - pytorch_modeler.py - INFO - epoch:39/200, tr_loss:7561.070343
# 100%|██████████| 24/24 [00:24<00:00,  1.02s/it]
# 2021-08-13 00:50:34,963 - pytorch_modeler.py - INFO - epoch:40/200, tr_loss:7356.407135
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 2021-08-13 00:51:00,546 - pytorch_modeler.py - INFO - epoch:41/200, tr_loss:7232.287933
# 100%|██████████| 24/24 [00:24<00:00,  1.03s/it]
# 2021-08-13 00:51:25,357 - pytorch_modeler.py - INFO - epoch:42/200, tr_loss:7274.237244
# 100%|██████████| 24/24 [00:25<00:00,  1.05s/it]
# 2021-08-13 00:51:50,550 - pytorch_modeler.py - INFO - epoch:43/200, tr_loss:7250.861145
# 100%|██████████| 24/24 [00:24<00:00,  1.04s/it]
# 2021-08-13 00:52:15,491 - pytorch_modeler.py - INFO - epoch:44/200, tr_loss:7119.985168
# 100%|██████████| 24/24 [00:24<00:00,  1.02s/it]
# 2021-08-13 00:52:39,997 - pytorch_modeler.py - INFO - epoch:45/200, tr_loss:7046.163391
# 100%|██████████| 24/24 [00:24<00:00,  1.01s/it]
# 2021-08-13 00:53:04,302 - pytorch_modeler.py - INFO - epoch:46/200, tr_loss:6933.945831
# 100%|██████████| 24/24 [00:27<00:00,  1.15s/it]
# 2021-08-13 00:53:31,976 - pytorch_modeler.py - INFO - epoch:47/200, tr_loss:6800.504684
# 100%|██████████| 24/24 [00:27<00:00,  1.14s/it]
# 2021-08-13 00:53:59,459 - pytorch_modeler.py - INFO - epoch:48/200, tr_loss:6666.992615
# 100%|██████████| 24/24 [00:26<00:00,  1.09s/it]
# 2021-08-13 00:54:25,549 - pytorch_modeler.py - INFO - epoch:49/200, tr_loss:6728.551331
# 100%|██████████| 24/24 [00:24<00:00,  1.03s/it]
# 2021-08-13 00:54:50,266 - pytorch_modeler.py - INFO - epoch:50/200, tr_loss:6499.771103
# 100%|██████████| 24/24 [00:25<00:00,  1.05s/it]
# 2021-08-13 00:55:15,540 - pytorch_modeler.py - INFO - epoch:51/200, tr_loss:6385.827530
# 100%|██████████| 24/24 [00:24<00:00,  1.02s/it]
# 2021-08-13 00:55:40,079 - pytorch_modeler.py - INFO - epoch:52/200, tr_loss:6325.806381
# 100%|██████████| 24/24 [00:25<00:00,  1.08s/it]
# 2021-08-13 00:56:06,004 - pytorch_modeler.py - INFO - epoch:53/200, tr_loss:6264.886520
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 2021-08-13 00:56:31,807 - pytorch_modeler.py - INFO - epoch:54/200, tr_loss:6071.935883
# 100%|██████████| 24/24 [00:24<00:00,  1.04s/it]
# 2021-08-13 00:56:56,722 - pytorch_modeler.py - INFO - epoch:55/200, tr_loss:6240.449448
# 100%|██████████| 24/24 [00:26<00:00,  1.11s/it]
# 2021-08-13 00:57:23,249 - pytorch_modeler.py - INFO - epoch:56/200, tr_loss:6034.573761
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 2021-08-13 00:57:48,985 - pytorch_modeler.py - INFO - epoch:57/200, tr_loss:5867.877731
# 100%|██████████| 24/24 [00:25<00:00,  1.06s/it]
# 2021-08-13 00:58:14,474 - pytorch_modeler.py - INFO - epoch:58/200, tr_loss:5709.151276
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 2021-08-13 00:58:40,276 - pytorch_modeler.py - INFO - epoch:59/200, tr_loss:5587.866776
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 2021-08-13 00:59:05,947 - pytorch_modeler.py - INFO - epoch:60/200, tr_loss:5647.609756
# 100%|██████████| 24/24 [00:23<00:00,  1.01it/s]
# 2021-08-13 00:59:29,789 - pytorch_modeler.py - INFO - epoch:61/200, tr_loss:5584.700226
# 100%|██████████| 24/24 [00:25<00:00,  1.05s/it]
# 2021-08-13 00:59:54,877 - pytorch_modeler.py - INFO - epoch:62/200, tr_loss:5565.134705
# 100%|██████████| 24/24 [00:24<00:00,  1.02s/it]
# 2021-08-13 01:00:19,292 - pytorch_modeler.py - INFO - epoch:63/200, tr_loss:5584.823151
# 100%|██████████| 24/24 [00:24<00:00,  1.02s/it]
# 2021-08-13
# 100%|██████████| 24/24 [00:23<00:00,  1.02it/s]
# 2021-08-13 01:39:44,518 - pytorch_modeler.py - INFO - epoch:163/200, tr_loss:3306.623665
# 100%|██████████| 24/24 [00:25<00:00,  1.06s/it]
# 2021-08-13 01:40:09,947 - pytorch_modeler.py - INFO - epoch:164/200, tr_loss:3319.305771
# 100%|██████████| 24/24 [00:25<00:00,  1.05s/it]
# 2021-08-13 01:40:35,235 - pytorch_modeler.py - INFO - epoch:165/200, tr_loss:3309.447990
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 2021-08-13 01:41:00,866 - pytorch_modeler.py - INFO - epoch:166/200, tr_loss:3318.062408
# 100%|██████████| 24/24 [00:24<00:00,  1.03s/it]
# 2021-08-13 01:41:25,470 - pytorch_modeler.py - INFO - epoch:167/200, tr_loss:3302.152870
# 100%|██████████| 24/24 [00:23<00:00,  1.01it/s]
# 2021-08-13 01:41:49,298 - pytorch_modeler.py - INFO - epoch:168/200, tr_loss:3236.686760
# 100%|██████████| 24/24 [00:24<00:00,  1.00s/it]
# 2021-08-13 01:42:13,402 - pytorch_modeler.py - INFO - epoch:169/200, tr_loss:3270.726578
# 100%|██████████| 24/24 [00:23<00:00,  1.01it/s]
# 2021-08-13 01:42:37,167 - pytorch_modeler.py - INFO - epoch:170/200, tr_loss:3287.083969
# 100%|██████████| 24/24 [00:23<00:00,  1.02it/s]
# 2021-08-13 01:43:00,779 - pytorch_modeler.py - INFO - epoch:171/200, tr_loss:3378.094315
# 100%|██████████| 24/24 [00:23<00:00,  1.02it/s]
# 2021-08-13 01:43:24,394 - pytorch_modeler.py - INFO - epoch:172/200, tr_loss:3314.264328
# 100%|██████████| 24/24 [00:23<00:00,  1.02it/s]
# 2021-08-13 01:43:47,897 - pytorch_modeler.py - INFO - epoch:173/200, tr_loss:3287.599579
# 100%|██████████| 24/24 [00:24<00:00,  1.01s/it]
# 2021-08-13 01:44:12,123 - pytorch_modeler.py - INFO - epoch:174/200, tr_loss:3163.494621
# 100%|██████████| 24/24 [00:23<00:00,  1.02it/s]
# 2021-08-13 01:44:35,762 - pytorch_modeler.py - INFO - epoch:175/200, tr_loss:3219.839630
# 100%|██████████| 24/24 [00:23<00:00,  1.02it/s]
# 2021-08-13 01:44:59,357 - pytorch_modeler.py - INFO - epoch:176/200, tr_loss:3223.782921
# 100%|██████████| 24/24 [00:23<00:00,  1.01it/s]
# 2021-08-13 01:45:23,106 - pytorch_modeler.py - INFO - epoch:177/200, tr_loss:3259.398796
# 100%|██████████| 24/24 [00:23<00:00,  1.02it/s]
# 2021-08-13 01:45:46,663 - pytorch_modeler.py - INFO - epoch:178/200, tr_loss:3325.405289
# 100%|██████████| 24/24 [00:23<00:00,  1.00it/s]
# 2021-08-13 01:46:10,650 - pytorch_modeler.py - INFO - epoch:179/200, tr_loss:3294.425407
# 100%|██████████| 24/24 [00:24<00:00,  1.00s/it]
# 2021-08-13 01:46:34,663 - pytorch_modeler.py - INFO - epoch:180/200, tr_loss:3217.744225
# 100%|██████████| 24/24 [00:23<00:00,  1.02it/s]
# 2021-08-13 01:46:58,197 - pytorch_modeler.py - INFO - epoch:181/200, tr_loss:3135.410118
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:47:21,554 - pytorch_modeler.py - INFO - epoch:182/200, tr_loss:3102.025665
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:47:44,856 - pytorch_modeler.py - INFO - epoch:183/200, tr_loss:3116.409149
# 100%|██████████| 24/24 [00:23<00:00,  1.01it/s]
# 2021-08-13 01:48:08,565 - pytorch_modeler.py - INFO - epoch:184/200, tr_loss:3144.373909
# 100%|██████████| 24/24 [00:23<00:00,  1.01it/s]
# 2021-08-13 01:48:32,305 - pytorch_modeler.py - INFO - epoch:185/200, tr_loss:3136.750443
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:48:55,653 - pytorch_modeler.py - INFO - epoch:186/200, tr_loss:3150.704956
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:49:19,055 - pytorch_modeler.py - INFO - epoch:187/200, tr_loss:3120.701828
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:49:42,403 - pytorch_modeler.py - INFO - epoch:188/200, tr_loss:3054.767204
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:50:05,772 - pytorch_modeler.py - INFO - epoch:189/200, tr_loss:2998.152878
# 100%|██████████| 24/24 [00:24<00:00,  1.00s/it]
# 2021-08-13 01:50:29,843 - pytorch_modeler.py - INFO - epoch:190/200, tr_loss:3042.437119
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:50:53,121 - pytorch_modeler.py - INFO - epoch:191/200, tr_loss:3028.034805
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:51:16,488 - pytorch_modeler.py - INFO - epoch:192/200, tr_loss:3057.179749
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:51:39,839 - pytorch_modeler.py - INFO - epoch:193/200, tr_loss:2965.784019
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:52:03,196 - pytorch_modeler.py - INFO - epoch:194/200, tr_loss:3020.873444
# 100%|██████████| 24/24 [00:23<00:00,  1.01it/s]
# 2021-08-13 01:52:26,994 - pytorch_modeler.py - INFO - epoch:195/200, tr_loss:2992.425873
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:52:50,344 - pytorch_modeler.py - INFO - epoch:196/200, tr_loss:3001.317909
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:53:13,680 - pytorch_modeler.py - INFO - epoch:197/200, tr_loss:3000.326195
# 100%|██████████| 24/24 [00:23<00:00,  1.03it/s]
# 2021-08-13 01:53:37,002 - pytorch_modeler.py - INFO - epoch:198/200, tr_loss:2939.537758
# 100%|██████████| 24/24 [00:23<00:00,  1.02it/s]
# 2021-08-13 01:54:00,494 - pytorch_modeler.py - INFO - epoch:199/200, tr_loss:2966.650757
# 100%|██████████| 24/24 [00:23<00:00,  1.00it/s]
# 2021-08-13 01:54:24,486 - pytorch_modeler.py - INFO - epoch:200/200, tr_loss:2991.295433
# 2021-08-13 01:54:24,698 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/DCASE_experiments/SSL-Efficientnet_Barlow_Twins_mixup_0.4_batchnorm/dcase2021_task2/models/fan_model.pkl
# 2021-08-13 01:54:24,700 - 00_train.py - INFO - TARGET MACHINE_TYPE: gearbox
# 2021-08-13 01:54:24,700 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-08-13 01:54:24,701 - 00_train.py - INFO - FEATURE EXTRACTION
#   0%|          | 0/24 [00:00<?, ?it/s]
# elapsed time: 4873.799526930 [sec]
# use: cuda:0
# 100%|██████████| 24/24 [00:54<00:00,  2.28s/it]
# 2021-08-13 01:55:19,656 - pytorch_modeler.py - INFO - epoch:1/200, tr_loss:29568.556519
# 100%|██████████| 24/24 [00:23<00:00,  1.01it/s]
# 2021-08-13 01:55:43,484 - pytorch_modeler.py - INFO - epoch:2/200, tr_loss:27334.722900
# 100%|██████████| 24/24 [00:24<00:00,  1.00s/it]
# 2021-08-13 01:56:07,537 - pytorch_modeler.py - INFO - epoch:3/200, tr_loss:23925.589783
# 100%|██████████| 24/24 [00:24<00:00,  1.01s/it]
# 2021-08-13 01:56:31,899 - pytorch_modeler.py - INFO - epoch:4/200, tr_loss:22199.927612
#  79%|███████▉  | 19/24 [00:20<00:05,  1.09s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-2349e03e993b> in <module>
#       1 for machine_type in machine_types:
# ----> 2     run(machine_type, dev_paths)
#
# <ipython-input-12-2dbd7a49ffb5> in run(machine_type, dev_paths)
#      17     optimizer = torch_optimizer.RAdam(net.parameters())
#      18     #scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.001, steps_per_epoch=len(dataloaders_dict['train']), epochs=config['param']['num_epochs'])
# ---> 19     output_dicts = modeler.train_net(net, dataloaders_dict, writer, optimizer)
#      20
#      21     out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
#
# ~/research/DCASE_experiments/dcase2021/SSL-Efficientnet_Barlow_Twins_mixup_0.4_batchnorm/pytorch_modeler.py in train_net(net, dataloaders_dict, writer, optimizer, lambd)
#     243                 label = sample['label'].to('cpu')
#     244                 labels.append(label)
# --> 245                 scaler.scale(loss).backward()
#     246                 scaler.step(optimizer)
#     247                 scaler.update()
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:
