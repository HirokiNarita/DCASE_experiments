# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle
import random
from random import sample

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from pytorch_model import Conditional_VAE as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_file = config['IO_OPTION']['OUTPUT_ROOT']+'/train_{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_file, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(777)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
#dev_dir = INPUT_ROOT + "/dev_data"
#add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
OUT_SCORE_DIR = OUTPUT_ROOT + '/score'
OUT_PRED_DIR = OUTPUT_ROOT + '/pred'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(OUT_SCORE_DIR, exist_ok=True)
os.makedirs(OUT_PRED_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/DCASE_experiments/SSL-Efficientnet/dcase2021_task2/ano_VAE+Centerloss/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
#ext_data = pd.read_pickle(f'{INPUT_ROOT}/valve_features.pkl')

# %%
#train_features = ext_data['train']['features']

# %%
#train_features.shape

# %% [markdown]
# ## training

# %%
def random_feature_selection(x, t_d=3776, d=2048):
    idx = torch.tensor(sample(range(0, t_d), d)) # t_d(特徴量)の中からランダムにd個サンプリングする(ぜんぶやると重いから) # わからん
    # 0~t_d idxの中からランダムにd個サンプリングする
    x = np.take(x, idx, 1)
    return x

# %%
#ext_data['train'].keys()

# %%
#############################################################################
# run
#############################################################################
def run(machine_type):
    com.tic()
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dataloader
    ext_data = pd.read_pickle(f'{INPUT_ROOT}/{machine_type}_features.pkl')
    dataloaders_dict = modeler.make_dataloader(ext_data)
    # define writer for tensorbord
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    # out path
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    score_out_path = OUT_SCORE_DIR + '/{}_score.csv'.format(machine_type)
    pred_out_path = OUT_PRED_DIR + '/{}_pred.csv'.format(machine_type)
    logger.info('TRAINING')
    # parameter setting
    in_features = ext_data['train']['features'].shape[1]
    mid_size = config['param']['mid_size']
    latent_size = config['param']['latent_size']
    num_classes = 6
    net = Model(in_features, mid_size, latent_size, num_classes)
    optimizer = optim.Adam(net.parameters(), lr=1e-4)
    num_epochs = config['param']['num_epochs']
    #scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e-2, 
    #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    # training
    output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
    
    com.toc()

# %%
machine_types
# Out:
# ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']

# %%
#path='/media/hiroki/HDD1TB/research/dcase2021_task2/output/CenterLossVAE/test_ex22/models/ToyCar_model.pth'
#pretrained_dict = torch.load(path)

# %%
#pretrained_dict['center_loss.centers'].shape

# %%
#pretrained_dict['center_loss.centers']

# %%
# for machine_type in machine_types:
#     run(machine_type)
# Out:
# 2021-08-10 20:34:46,559 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyCar
# 2021-08-10 20:34:46,559 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-08-10 20:34:47,399 - 00_train.py - INFO - TRAINING
# 2021-08-10 20:34:50,737 - pytorch_modeler.py - INFO - train
#   0%|          | 0/12 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 12/12 [00:00<00:00, 14.33it/s]
# 2021-08-10 20:34:51,578 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 97.39it/s]
# 2021-08-10 20:34:51,623 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 89.39it/s]
#                AUC      pAUC
# Source_0  0.477100  0.522632
# Source_1  0.570200  0.515263
# Source_2  0.456200  0.497368
# Target_0  0.482300  0.506316
# Target_1  0.534100  0.504211
# Target_2  0.417500  0.509474
# mean      0.489567  0.509211
# h_mean    0.484547  0.509083
# 2021-08-10 20:34:52,800 - pytorch_modeler.py - INFO - epoch:1/300, train_losses:35904.303874, val_AUC_hmean:0.484547, val_pAUC_hmean:0.509083, best_flag:True
# 2021-08-10 20:34:52,800 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 28.04it/s]
# 2021-08-10 20:34:53,230 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 94.22it/s]
# 2021-08-10 20:34:53,274 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 92.65it/s]
# 2021-08-10 20:34:53,319 - pytorch_modeler.py - INFO - epoch:2/300, train_losses:28549.728190, val_AUC_hmean:0.455917, val_pAUC_hmean:0.503541, best_flag:False
# 2021-08-10 20:34:53,320 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.12it/s]
# 2021-08-10 20:34:53,764 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 99.23it/s]
# 2021-08-10 20:34:53,806 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 96.53it/s]
# 2021-08-10 20:34:53,849 - pytorch_modeler.py - INFO - epoch:3/300, train_losses:26020.755859, val_AUC_hmean:0.440820, val_pAUC_hmean:0.502330, best_flag:False
# 2021-08-10 20:34:53,851 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 28.06it/s]
# 2021-08-10 20:34:54,281 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 98.65it/s]
# 2021-08-10 20:34:54,320 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 103.67it/s]
# 2021-08-10 20:34:54,362 - pytorch_modeler.py - INFO - epoch:4/300, train_losses:24557.600749, val_AUC_hmean:0.436288, val_pAUC_hmean:0.501056, best_flag:False
# 2021-08-10 20:34:54,363 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.61it/s]
# 2021-08-10 20:34:54,896 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 82.46it/s]
# 2021-08-10 20:34:54,940 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 107.64it/s]
# 2021-08-10 20:34:54,980 - pytorch_modeler.py - INFO - epoch:5/300, train_losses:23501.524089, val_AUC_hmean:0.433551, val_pAUC_hmean:0.505648, best_flag:False
# 2021-08-10 20:34:54,981 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.28it/s]
# 2021-08-10 20:34:55,423 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 86.05it/s]
# 2021-08-10 20:34:55,466 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 96.08it/s]
# 2021-08-10 20:34:55,510 - pytorch_modeler.py - INFO - epoch:6/300, train_losses:22668.656738, val_AUC_hmean:0.432314, val_pAUC_hmean:0.507087, best_flag:False
# 2021-08-10 20:34:55,511 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 25.71it/s]
# 2021-08-10 20:34:55,980 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 79.60it/s]
# 2021-08-10 20:34:56,026 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 75.62it/s]
#                AUC      pAUC
# Source_0  0.528500  0.539474
# Source_1  0.584500  0.537895
# Source_2  0.319800  0.486842
# Target_0  0.466100  0.494737
# Target_1  0.594400  0.528947
# Target_2  0.304200  0.485263
# mean      0.466250  0.512193
# h_mean    0.433366  0.511101
# 2021-08-10 20:34:57,149 - pytorch_modeler.py - INFO - epoch:7/300, train_losses:21994.395345, val_AUC_hmean:0.433366, val_pAUC_hmean:0.511101, best_flag:True
# 2021-08-10 20:34:57,150 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 25.23it/s]
# 2021-08-10 20:34:57,628 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 103.58it/s]
# 2021-08-10 20:34:57,667 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 106.39it/s]
#                AUC      pAUC
# Source_0  0.545000  0.550000
# Source_1  0.590600  0.539474
# Source_2  0.342000  0.486842
# Target_0  0.470600  0.493684
# Target_1  0.595600  0.544737
# Target_2  0.302100  0.485263
# mean      0.474317  0.516667
# h_mean    0.442278  0.515111
# 2021-08-10 20:34:58,757 - pytorch_modeler.py - INFO - epoch:8/300, train_losses:21462.208333, val_AUC_hmean:0.442278, val_pAUC_hmean:0.515111, best_flag:True
# 2021-08-10 20:34:58,757 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27
- pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 77.15it/s]
# 2021-08-10 20:35:38,096 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 83.59it/s]
# 2021-08-10 20:35:38,143 - pytorch_modeler.py - INFO - epoch:71/300, train_losses:11854.564453, val_AUC_hmean:0.493538, val_pAUC_hmean:0.521461, best_flag:False
# 2021-08-10 20:35:38,144 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.51it/s]
# 2021-08-10 20:35:38,599 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 93.18it/s]
# 2021-08-10 20:35:38,638 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 74.40it/s]
# 2021-08-10 20:35:38,687 - pytorch_modeler.py - INFO - epoch:72/300, train_losses:11905.704346, val_AUC_hmean:0.482709, val_pAUC_hmean:0.527514, best_flag:False
# 2021-08-10 20:35:38,688 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.88it/s]
# 2021-08-10 20:35:39,137 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 89.99it/s]
# 2021-08-10 20:35:39,177 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 88.52it/s]
# 2021-08-10 20:35:39,223 - pytorch_modeler.py - INFO - epoch:73/300, train_losses:11673.841471, val_AUC_hmean:0.498486, val_pAUC_hmean:0.519980, best_flag:False
# 2021-08-10 20:35:39,224 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.33it/s]
# 2021-08-10 20:35:39,665 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 92.30it/s]
# 2021-08-10 20:35:39,705 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 93.75it/s]
# 2021-08-10 20:35:39,750 - pytorch_modeler.py - INFO - epoch:74/300, train_losses:11523.184733, val_AUC_hmean:0.486189, val_pAUC_hmean:0.523158, best_flag:False
# 2021-08-10 20:35:39,751 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.22it/s]
# 2021-08-10 20:35:40,193 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 90.50it/s]
# 2021-08-10 20:35:40,233 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 91.73it/s]
# 2021-08-10 20:35:40,284 - pytorch_modeler.py - INFO - epoch:75/300, train_losses:11512.060791, val_AUC_hmean:0.489220, val_pAUC_hmean:0.523098, best_flag:False
# 2021-08-10 20:35:40,286 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.10it/s]
# 2021-08-10 20:35:40,730 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 76.75it/s]
# 2021-08-10 20:35:40,777 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 85.03it/s]
# 2021-08-10 20:35:40,823 - pytorch_modeler.py - INFO - epoch:76/300, train_losses:11346.281331, val_AUC_hmean:0.483314, val_pAUC_hmean:0.524286, best_flag:False
# 2021-08-10 20:35:40,825 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.24it/s]
# 2021-08-10 20:35:41,270 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 98.11it/s]
# 2021-08-10 20:35:41,308 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 90.21it/s]
# 2021-08-10 20:35:41,352 - pytorch_modeler.py - INFO - epoch:77/300, train_losses:11389.595459, val_AUC_hmean:0.487547, val_pAUC_hmean:0.517994, best_flag:False
# 2021-08-10 20:35:41,353 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.70it/s]
# 2021-08-10 20:35:41,788 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 105.94it/s]
# 2021-08-10 20:35:41,825 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 100.46it/s]
# 2021-08-10 20:35:41,872 - pytorch_modeler.py - INFO - epoch:78/300, train_losses:11332.125244, val_AUC_hmean:0.494496, val_pAUC_hmean:0.523441, best_flag:False
# 2021-08-10 20:35:41,873 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.85it/s]
# 2021-08-10 20:35:42,321 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 89.43it/s]
# 2021-08-10 20:35:42,363 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 88.55it/s]
# 2021-08-10 20:35:42,407 - pytorch_modeler.py - INFO - epoch:79/300, train_losses:11085.277018, val_AUC_hmean:0.500424, val_pAUC_hmean:0.523516, best_flag:False
# 2021-08-10 20:35:42,408 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.35it/s]
# 2021-08-10 20:35:42,849 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 94.32it/s]
# 2021-08-10 20:35:42,889 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 82.53it/s]
# 2021-08-10 20:35:42,934 - pytorch_modeler.py - INFO - epoch:80/300, train_losses:11109.192627, val_AUC_hmean:0.485226, val_pAUC_hmean:0.520299, best_flag:False
# 2021-08-10 20:35:42,936 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.82it/s]
# 2021-08-10 20:35:43,385 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 83.43it/s]
# 2021-08-10 20:35:43,427 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 80.28it/s]
# 2021-08-10 20:35:43,475 - pytorch_modeler.py - INFO - epoch:81/300, train_losses:11079.922119, val_AUC_hmean:0.482427, val_pAUC_hmean:0.516782, best_flag:False
# 2021-08-10 20:35:43,476 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.05it/s]
# 2021-08-10 20:35:43,921 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 86.60it/s]
# 2021-08-10 20:35:43,964 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 89.11it/s]
# 2021-08-10 20:35:44,008 - pytorch_modeler.py - INFO - epoch:82/300, train_losses:10957.057210, val_AUC_hmean:0.489078, val_pAUC_hmean:0.523306, best_flag:False
# 2021-08-10 20:35:44,009 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.82it/s]
# 2021-08-10 20:35:44,459 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 80.17it/s]
# 2021-08-10 20:35:44,503 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 84.11it/s]
# 2021-08-10 20:35:44,549 - pytorch_modeler.py - INFO - epoch:83/300, train_losses:10912.679281, val_AUC_hmean:0.492153, val_pAUC_hmean:0.520216, best_flag:False
# 2021-08-10 20:35:44,550 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.02it/s]
# 2021-08-10 20:35:44,996 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 81.44it/s]
# 2021-08-10 20:35:45,038 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 80.55it/s]
# 2021-08-10 20:35:45,084 - pytorch_modeler.py - INFO - epoch:84/300, train_losses:10852.903483, val_AUC_hmean:0.499330, val_pAUC_hmean:0.523699, best_flag:False
# 2021-08-10 20:35:45,085 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.09it/s]
# 2021-08-10 20:35:45,530 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 91.92it/s]
# 2021-08-10 20:35:45,570 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 83.89it/s]
# 2021-08-10 20:35:45,616 - pytorch_modeler.py - INFO - epoch:85/300, train_losses:10871.857178, val_AUC_hmean:0.491814, val_pAUC_hmean:0.518710, best_flag:False
# 2021-08-10 20:35:45,617 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.51it/s]
# 2021-08-10 20:35:46,055 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 91.21it/s]
# 2021-08-10 20:35:46,096 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 88.04it/s]
# 2021-08-10 20:35:46,141 - pytorch_modeler.py - INFO - epoch:86/300, train_losses:10756.062500, val_AUC_hmean:0.499093, val_pAUC_hmean:0.522311, best_flag:False
# 2021-08-10 20:35:46,143 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.77it/s]
# 2021-08-10 20:35:46,593 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 79.53it/s]
# 2021-08-10 20:35:46,637 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 77.03it/s]
# 2021-08-10 20:35:46,687 - pytorch_modeler.py - INFO - epoch:87/300, train_losses:10730.940511, val_AUC_hmean:0.497443, val_pAUC_hmean:0.521513, best_flag:False
# 2021-08-10 20:35:46,688 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.49it/s]
# 2021-08-10 20:35:47,145 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 81.35it/s]
# 2021-08-10 20:35:47,188 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 80.41it/s]
# 2021-08-10 20:35:47,235 - pytorch_modeler.py - INFO - epoch:88/300, train_losses:10644.290609, val_AUC_hmean:0.495021, val_pAUC_hmean:0.522404, best_flag:False
# 2021-08-10 20:35:47,236 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.56it/s]
# 2021-08-10 20:35:47,795 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 88.96it/s]
# 2021-08-10 20:35:47,835 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 81.16it/s]
# 2021-08-10 20:35:47,881 - pytorch_modeler.py - INFO - epoch:89/300, train_losses:10602.420166, val_AUC_hmean:0.491685, val_pAUC_hmean:0.519979, best_flag:False
# 2021-08-10 20:35:47,882 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.17it/s]
# 2021-08-10 20:35:48,326 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 92.35it/s]
# 2021-08-10 20:35:48,365 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 94.08it/s]
# 2021-08-10 20:35:48,410 - pytorch_modeler.py - INFO - epoch:90/300, train_losses:10608.196208, val_AUC_hmean:0.479151, val_pAUC_hmean:0.521576, best_flag:False
# 2021-08-10 20:35:48,411 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.48it/s]
# 2021-08-10 20:35:48,850 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 92.47it/s]
# 2021-08-10 20:35:48,889 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 98.67it/s]
# 2021-08-10 20:35:48,936 - pytorch_modeler.py - INFO - epoch:91/300, train_losses:10547.137288, val_AUC_hmean:0.496337, val_pAUC_hmean:0.519124, best_flag:False
# 2021-08-10 20:35:48,938 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.14it/s]
# 2021-08-10 20:35:49,382 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 95.65it/s]
# 2021-08-10 20:35:49,420 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 98.42it/s]
# 2021-08-10 20:35:49,464 - pytorch_modeler.py - INFO - epoch:92/300, train_losses:10435.502116, val_AUC_hmean:0.490425, val_pAUC_hmean:0.522464, best_flag:False
# 2021-08-10 20:35:49,465 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.46it/s]
# 2021-08-10 20:35:49,903 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 86.72it/s]
# 2021-08-10 20:35:49,945 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 83.52it/s]
# 2021-08-10 20:35:49,993 - pytorch_modeler.py - INFO - epoch:93/300, train_losses:10421.719727, val_AUC_hmean:0.490722, val_pAUC_hmean:0.515416, best_flag:False
# 2021-08-10 20:35:49,994 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.39it/s]
# 2021-08-10 20:35:50,434 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 100.16it/s]
# 2021-08-10 20:35:50,472 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 90.45it/s]
# 2021-08-10 20:35:50,515 - pytorch_modeler.py - INFO - epoch:94/300, train_losses:10368.858724, val_AUC_hmean:0.484915, val_pAUC_hmean:0.519625, best_flag:False
# 2021-08-10 20:35:50,516 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.17it/s]
# 2021-08-10 20:35:50,960 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 92.33it/s]
# 2021-08-10 20:35:51,002 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 91.16it/s]
# 2021-08-10 20:35:51,049 - pytorch_modeler.py - INFO - epoch:95/300, train_losses:10336.341878, val_AUC_hmean:0.495889, val_pAUC_hmean:0.514414, best_flag:False
# 2021-08-10 20:35:51,051 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.30it/s]
# 2021-08-10 20:35:51,492 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 87.05it/s]
# 2021-08-10 20:35:51,533 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 90.53it/s]
# 2021-08-10 20:35:51,583 - pytorch_modeler.py - INFO - epoch:96/300, train_losses:10298.064860, val_AUC_hmean:0.488500, val_pAUC_hmean:0.517946, best_flag:False
# 2021-08-10 20:35:51,585 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.92it/s]
# 2021-08-10 20:35:52,034 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 86.52it/s]
# 2021-08-10 20:35:52,074 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 82.77it/s]
# 2021-08-10 20:35:52,120 - pytorch_modeler.py - INFO - epoch:97/300, train_losses:10174.438802, val_AUC_hmean:0.486113, val_pAUC_hmean:0.514097, best_flag:False
# 2021-08-10 20:35:52,121 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.11it/s]
# 2021-08-10 20:35:52,565 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 95.05it/s]
# 2021-08-10 20:35:52,604 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 78.65it/s]
# 2021-08-10 20:35:52,651 - pytorch_modeler.py - INFO - epoch:98/300, train_losses:10131.727702, val_AUC_hmean:0.495108, val_pAUC_hmean:0.516676, best_flag:False
# 2021-08-10 20:35:52,652 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.36it/s]
# 2021-08-10 20:35:53,093 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 87.36it/s]
# 2021-08-10 20:35:53,133 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 90.54it/s]
# 2021-08-10 20:35:53,177 - pytorch_modeler.py - INFO - epoch:99/300, train_losses:10245.467529, val_AUC_hmean:0.499206, val_pAUC_hmean:0.517531, best_flag:False
# 2021-08-10 20:35:53,178 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.53it/s]
# 2021-08-10 20:35:53,616 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 88.45it/s]
# 2021-08-10 20:35:53,656 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 88.26it/s]
# 2021-08-10 20:35:53,700 - pytorch_modeler.py - INFO - epoch:100/300, train_losses:10099.887695, val_AUC_hmean:0.493520, val_pAUC_hmean:0.520375, best_flag:False
# 2021-08-10 20:35:53,702 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.56it/s]
# 2021-08-10 20:35:54,155 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 86.78it/s]
# 2021-08-10 20:35:54,197 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 90.56it/s]
# 2021-08-10 20:35:54,243 - pytorch_modeler.py - INFO - epoch:101/300, train_losses:9995.978597, val_AUC_hmean:0.494279, val_pAUC_hmean:0.514285, best_flag:False
# 2021-08-10 20:35:54,244 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 23.78it/s]
# 2021-08-10 20:35:54,751 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 98.13it/s]
# 2021-08-10 20:35:54,794 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 88.66it/s]
# 2021-08-10 20:35:54,845 - pytorch_modeler.py - INFO - epoch:102/300, train_losses:9946.854492, val_AUC_hmean:0.498341, val_pAUC_hmean:0.520526, best_flag:False
# 2021-08-10 20:35:54,847 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 25.42it/s]
# 2021-08-10 20:35:55,321 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 88.69it/s]
# 2021-08-10 20:35:55,368 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 87.71it/s]
# 2021-08-10 20:35:55,421 - pytorch_modeler.py - INFO - epoch:103/300, train_losses:9897.453044, val_AUC_hmean:0.491510, val_pAUC_hmean:0.518632, best_flag:False
# 2021-08-10 20:35:55,422 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.67it/s]
# 2021-08-10 20:35:55,874 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 88.64it/s]
# 2021-08-10 20:35:55,914 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 91.93it/s]
# 2021-08-10 20:35:55,961 - pytorch_modeler.py - INFO - epoch:104/300, train_losses:9846.449707, val_AUC_hmean:0.487951, val_pAUC_hmean:0.527206, best_flag:False
# 2021-08-10 20:35:55,963 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.92it/s]
# 2021-08-10 20:35:56,410 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 82.83it/s]
# 2021-08-10 20:35:56,454 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 100.93it/s]
# 2021-08-10 20:35:56,497 - pytorch_modeler.py - INFO - epoch:105/300, train_losses:9818.000895, val_AUC_hmean:0.485636, val_pAUC_hmean:0.521083, best_flag:False
# 2021-08-10 20:35:56,498 - pytorch_modeler.py - INFO - train
#  33%|███▎      | 4/12 [00:00<00:00, 21.02it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-9c47a29ad1dc> in <module>
#       1 for machine_type in machine_types:
# ----> 2     run(machine_type)
#
# <ipython-input-13-1fc73bb08e36> in run(machine_type)
#      29     #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
#      30     # training
# ---> 31     output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#      32
#      33     com.toc()
#
# ~/research/DCASE_experiments/dcase2021/SSL-Efficientnet/ano_VAE+Centerloss/pytorch_modeler.py in train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#     135                     optimizer.step()
#     136                     #scheduler.step()
# --> 137                     tr_losses += loss.item()
#     138
#     139                 tr_losses = tr_losses / len(dataloaders_dict[phase])
#
# KeyboardInterrupt:

# %%
run(machine_types[1])
