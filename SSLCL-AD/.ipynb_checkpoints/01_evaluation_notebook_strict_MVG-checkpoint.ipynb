# %%
import yaml
yaml.warnings({'YAMLLoadWarning': False})
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']

# %% [markdown]
# # load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
import scipy
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# original library
sys.path.append('../../')
import common as com
import pytorch_modeler as modeler

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# ML lib
from scipy.stats import zscore
#from umap import UMAP
#from sklearn.mixture import GaussianMixture
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import mahalanobis


import librosa
import IPython
import librosa.display

# %% [markdown]
# # load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/eval_strict_MVG_{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '01_eval.py')

# %% [markdown]
# # Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
OUT_SCORE_DIR = OUTPUT_ROOT + '/score_strict'
OUT_PRED_DIR = OUTPUT_ROOT + '/pred_strict'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(OUT_SCORE_DIR, exist_ok=True)
os.makedirs(OUT_PRED_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/CL-VAE_experiments/output/extract_features/config.yaml'

# %%
#score = pd.read_csv(f'{OUT_SCORE_DIR}/{machine_types[0]}_score.csv', index_col=0)

# %%
#score.loc['h_mean']['pAUC']

# %% [markdown]
# # load data

# %%
machine_types
# Out:
# ['fan', 'pump', 'slider', 'ToyCar', 'ToyConveyor', 'valve']

# %%
data_types = ['train', 'dev_test']

# %%
def load_ext_data(machine_type):
    input_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    ext_data = pd.read_pickle(input_path)
    
    return ext_data

# %% [raw]
# machine_type = 'pump'
# input_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
# ext_data = pd.read_pickle(input_path)
#
#
# data_type = data_types[0]
# feats = ext_data[data_type]['features']
# labels = ext_data[data_type]['labels']
# data_types = [data_type] * len(ext_data[data_type]['labels'])

# %% [raw]
# for i, data_type in enumerate(data_types):
#     if i == 0:
#         feats = ext_data[data_type]['features']
#         labels = ext_data[data_type]['labels']
#         data_types = [data_type] * len(ext_data[data_type]['labels'])
#     else:
#         feats = np.concatenate([feats, ext_data[data_type]['features']], axis=0)
#         labels = np.concatenate([labels, ext_data[data_type]['labels']], axis=0)
#         # data type
#         data_type = [data_type] * len(ext_data[data_type]['labels'])
#         data_types = data_types + data_type

# %% [raw]
# wav_names = []
# for wav_name in ext_data[data_type]['wav_names']:
#     wav_names += wav_name

# %% [raw]
# len(wav_names)

# %%
# for train datasets
def get_target_names(wav_names):
    target_names = []
    for wav_name in wav_names:
        if 'target' in wav_name:
            target_names.append(wav_name)
    
    return target_names

# %% [markdown]
# for machine_type in machine_types:
#     data = load_ext_data(machine_type)
#     plt.figure(figsize=(10,10))
#     plt.imshow(data['train']['features'], aspect='auto')
#     plt.title(machine_type)
#     plt.colorbar()
#     plt.show()

# %% [markdown]
# for machine_type in machine_types:
#     data = load_ext_data(machine_type)
#     plt.figure(figsize=(10,10))
#     plt.imshow(data['dev_test']['features'], aspect='auto')
#     plt.title(machine_type)
#     plt.colorbar()
#     plt.show()

# %% [markdown]
# # evaluation

# %% [markdown]
# ## calc MVG (multivariate Gaussian)

# %%
ext_data = load_ext_data('ToyCar')

# %%
ext_data['train']['wav_names']
# Out:
# ['/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000000.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000001.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000002.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000003.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000004.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000005.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000006.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000007.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000008.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000009.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000010.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000011.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000012.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000013.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000014.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000015.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000016.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000017.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000018.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000019.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000020.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000021.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000022.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000023.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000024.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000025.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000026.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000027.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000028.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000029.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000030.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000031.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000032.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000033.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000034.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000035.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000036.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000037.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000038.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000039.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000040.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000041.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000042.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000043.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000044.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000045.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000046.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000047.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000048.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000049.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000050.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000051.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000052.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000053.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000054.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000055.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000056.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000057.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000058.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000059.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000060.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000061.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000062.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000063.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000064.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000065.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000066.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000067.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000068.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000069.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000070.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000071.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000072.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000073.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000074.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000075.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000076.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000077.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000078.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000079.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000080.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000081.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000082.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000083.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000084.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000085.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000086.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000087.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000088.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000089.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000090.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000091.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000092.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000093.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000094.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000095.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000096.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000097.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000098.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000099.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000100.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000101.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000102.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000103.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000104.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000105.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000106.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000107.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000108.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000109.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000110.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000111.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000112.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000113.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000114.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000115.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000116.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000117.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000118.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000119.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000120.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000121.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000122.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000123.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000124.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000125.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000126.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000127.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000128.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000129.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000130.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000131.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000132.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000133.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000134.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000135.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000136.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000137.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000138.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000139.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000140.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000141.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000142.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000143.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000144.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000145.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000146.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000147.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000148.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000149.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000150.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000151.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000152.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000153.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000154.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000155.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000156.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000157.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000158.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000159.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000160.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000161.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000162.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000163.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000164.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000165.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000166.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000167.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000168.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000169.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000170.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000171.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000172.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000173.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000174.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000175.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000176.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000177.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000178.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000179.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000180.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000181.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000182.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000183.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000184.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000185.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000186.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000187.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000188.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000189.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000190.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000191.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000192.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000193.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000194.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000195.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000196.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000197.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000198.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000199.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000200.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000201.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000202.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000203.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000204.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000205.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000206.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000207.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000208.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000209.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000210.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000211.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000212.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000213.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000214.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000215.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000216.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000217.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000218.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000219.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000220.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000221.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000222.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000223.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000224.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000225.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000226.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000227.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000228.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000229.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000230.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000231.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000232.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000233.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000234.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000235.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000236.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000237.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000238.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000239.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000240.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000241.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000242.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000243.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000244.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000245.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000246.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000247.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000248.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000249.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000250.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000251.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000252.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000253.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000254.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000255.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000256.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000257.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000258.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000259.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000260.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000261.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000262.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000263.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000264.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000265.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000266.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000267.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000268.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000269.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000270.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000271.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000272.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000273.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000274.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000275.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000276.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000277.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000278.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000279.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000280.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000281.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000282.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000283.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000284.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000285.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000286.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000287.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000288.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000289.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000290.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000291.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000292.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000293.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000294.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000295.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000296.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000297.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000298.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000299.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000300.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000301.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000302.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000303.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000304.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000305.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000306.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000307.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000308.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000309.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000310.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000311.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000312.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000313.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000314.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000315.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000316.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000317.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000318.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000319.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000320.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000321.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000322.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000323.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000324.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000325.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000326.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000327.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000328.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000329.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000330.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000331.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000332.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000333.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000334.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000335.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000336.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000337.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000338.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000339.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000340.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000341.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000342.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000343.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000344.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000345.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000346.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000347.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000348.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000349.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000350.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000351.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000352.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000353.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000354.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000355.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000356.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000357.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000358.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000359.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000360.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000361.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000362.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000363.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000364.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000365.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000366.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000367.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000368.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000369.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000370.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000371.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000372.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000373.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000374.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000375.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000376.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000377.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000378.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000379.wav',
# ...
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000874.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000875.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000876.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000877.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000878.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000879.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000880.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000881.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000882.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000883.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000884.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000885.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000886.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000887.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000888.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000889.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000890.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000891.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000892.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000893.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000894.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000895.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000896.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000897.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000898.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000899.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000900.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000901.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000902.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000903.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000904.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000905.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000906.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000907.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000908.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000909.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000910.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000911.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000912.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000913.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000914.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000915.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000916.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000917.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000918.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000919.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000920.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000921.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000922.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000923.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000924.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000925.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000926.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000927.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000928.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000929.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000930.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000931.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000932.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000933.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000934.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000935.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000936.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000937.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000938.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000939.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000940.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000941.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000942.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000943.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000944.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000945.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000946.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000947.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000948.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000949.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000950.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000951.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000952.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000953.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000954.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000955.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000956.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000957.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000958.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000959.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000960.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000961.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000962.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000963.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000964.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000965.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000966.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000967.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000968.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000969.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000970.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000971.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000972.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000973.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000974.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000975.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000976.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000977.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000978.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000979.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000980.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000981.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000982.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000983.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000984.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000985.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000986.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000987.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000988.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000989.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000990.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000991.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000992.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000993.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000994.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000995.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000996.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000997.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000998.wav',
#  '/media/hiroki/HDD1TB/research/CL-VAE_experiments/datasets/dcase2020_task2/dev_data/ToyCar/train/normal_id_01_00000999.wav',
#  ...]

# %%
com.get_id(ext_data['train']['wav_names'])
# Out:
# array([1, 1, 1, ..., 7, 7, 7])

# %%
com.tic()

MVG = {}

for machine_type in machine_types:
    MVG[machine_type] = {}
    ext_data = load_ext_data(machine_type)
    section_types = com.get_id(ext_data['train']['wav_names'])
    
    for section in np.unique(section_types):
        MVG[machine_type][section] = {}
        idx = np.where(section_types == section)
        per_section_samples = ext_data['train']['features'][idx]
        per_section_mean = per_section_samples.mean(axis=0)
        I = np.identity(per_section_samples.shape[1])
        per_section_cov = np.cov(per_section_samples, rowvar=False) + 0.01 * I
        #per_section_cov = cov_estimator.covariance_
        MVG[machine_type][section]['mean'] = per_section_mean
        MVG[machine_type][section]['cov'] = per_section_cov

com.toc()
# Out:
# elapsed time: 16.688820362 [sec]

# %%
plt.imshow(MVG[machine_type][0]['cov'], cmap='jet', aspect='auto')

# %% [markdown]
# ## estimate

# %%
from IPython.display import display

# %%
def get_score_perID(describe_df, max_fpr=0.1):
    # ユニークsectionを取得、昇順ソート
    sections = np.sort(describe_df['section_types'].unique())

    for section in sections:
        per_section_df = describe_df[describe_df['section_types'] == section]
        per_section_AUC = roc_auc_score(per_section_df['labels'], per_section_df['preds'])
        per_section_pAUC = roc_auc_score(per_section_df['labels'], per_section_df['preds'], max_fpr=max_fpr)
        # column = [AUC,pAUC], row = index
        score_df = pd.DataFrame(np.stack([per_section_AUC, per_section_pAUC]), index=['AUC', 'pAUC']).T
        # indexをsectionナンバーにrename
        # column = [AUC,pAUC], row = [section]
        score_df.index = [section]
        if section == 0:
            scores_df = score_df.copy()
        else:
            # 結合
            scores_df = scores_df.append(score_df)
    return scores_df

# %%
def calc_mahalanobis(mean, cov, samples):
    cov_inv = np.linalg.inv(cov)
    # load data
    dists = [mahalanobis(sample, mean, cov_inv) for sample in samples]
    # np.array
    dists = np.array(dists)
    return dists

# %% [markdown]
# ## Calc Score

# %%
# valid_dataloaderをシャッフルするとバグるの注意

for i, machine_type in enumerate(machine_types):
    logger.info('CALC SCORE')
    logger.info(machine_type)
    # get MVG
    #tr_mean = MVG[machine_type]['mean']
    #tr_cov = MVG[machine_type]['cov']
    # load samples
    ext_data = load_ext_data(machine_type)
    for phase in ['dev_test']:
        # pred
        samples = ext_data[phase]['features']
        section_types = com.get_id(ext_data[phase]['wav_names'])
        for section in np.unique(section_types):
            # get MVG
            tr_mean = MVG[machine_type][section]['mean']
            tr_cov = MVG[machine_type][section]['cov']
            idx = np.where(section_types == section)
            per_section_samples = ext_data[phase]['features'][idx]
            per_preds = calc_mahalanobis(tr_mean, tr_cov, per_section_samples)

            if section == np.unique(section_types)[0]:
                preds = per_preds.copy()
            else:
                preds = np.concatenate([preds, per_preds], axis=0)
        # wavname + pred
        preds_pd = np.stack([np.array(ext_data[phase]['wav_names']), preds], axis=1)
        preds_pd = pd.DataFrame(preds_pd, columns=['wav_name', 'pred'])
        preds_pd.to_csv(OUT_PRED_DIR + f'/pred_{machine_type}_{phase}.csv')
        # dataframe作成
        describe_df = com.get_pred_discribe(labels=ext_data[phase]['labels'],
                                            preds=preds,
                                            section_types=section_types,
                                            wav_names=ext_data[phase]['wav_names'])
        # スコア算出(AUC, pAUC)
        scores_df = com.get_score_per_Section(describe_df, max_fpr=0.1)

        # 結合(source + target)
        scores_df = scores_df.rename(index=lambda num: 'id_0' + f'{num}')
        all_scores_df = scores_df.copy()
            
    # 平均
    mean_df = pd.DataFrame(all_scores_df.mean(axis=0)).T
    mean_df.index = ['mean']
    # 調和平均
    hmean = scipy.stats.hmean(all_scores_df, axis=0)
    hmean_df = pd.DataFrame(hmean, index=['AUC', 'pAUC']).T
    hmean_df.index = ['h_mean']
    # 結合
    all_scores_df = all_scores_df.append(mean_df)
    all_scores_df = all_scores_df.append(hmean_df)
    # 出力
    all_scores_df.to_csv(f'{OUT_SCORE_DIR}/{machine_type}_score.csv')
    # display
    display(all_scores_df)
# Out:
# 2021-05-23 22:42:48,468 - 01_eval.py - INFO - CALC SCORE
# 2021-05-23 22:42:48,469 - 01_eval.py - INFO - fan
#                AUC      pAUC
# Source_0  0.698900  0.614211
# Source_1  0.620500  0.506842
# Source_2  0.596200  0.509474
# Target_0  0.744100  0.588947
# Target_1  0.563900  0.513158
# Target_2  0.603800  0.514211
# mean      0.637900  0.541140
# h_mean    0.632034  0.537861
# 2021-05-23 22:43:04,839 - 01_eval.py - INFO - CALC SCORE
# 2021-05-23 22:43:04,840 - 01_eval.py - INFO - gearbox
#                AUC      pAUC
# Source_0  0.716728  0.643339
# Source_1  0.944016  0.811205
# Source_2  0.735843  0.603639
# Target_0  0.911169  0.793596
# Target_1  0.955161  0.825013
# Target_2  0.795476  0.696742
# mean      0.843065  0.728922
# h_mean    0.831593  0.718461
# 2021-05-23 22:43:21,687 - 01_eval.py - INFO - CALC SCORE
# 2021-05-23 22:43:21,688 - 01_eval.py - INFO - pump
#                AUC      pAUC
# Source_0  0.665100  0.652105
# Source_1  0.681000  0.540526
# Source_2  0.649400  0.590526
# Target_0  0.527500  0.518947
# Target_1  0.524700  0.485263
# Target_2  0.576900  0.509474
# mean      0.604100  0.549474
# h_mean    0.597203  0.544096
# 2021-05-23 22:43:35,751 - 01_eval.py - INFO - CALC SCORE
# 2021-05-23 22:43:35,752 - 01_eval.py - INFO - slider
#                AUC      pAUC
# Source_0  0.724800  0.538421
# Source_1  0.888400  0.684737
# Source_2  0.782442  0.647716
# Target_0  0.588200  0.510526
# Target_1  0.543776  0.558969
# Target_2  0.629277  0.552905
# mean      0.692816  0.582212
# h_mean    0.673281  0.575927
# 2021-05-23 22:43:49,187 - 01_eval.py - INFO - CALC SCORE
# 2021-05-23 22:43:49,187 - 01_eval.py - INFO - ToyCar
#                AUC      pAUC
# Source_0  0.860200  0.647895
# Source_1  0.706600  0.565789
# Source_2  0.870700  0.701053
# Target_0  0.582100  0.566316
# Target_1  0.841800  0.698421
# Target_2  0.645700  0.590000
# mean      0.751183  0.628246
# h_mean    0.733424  0.623063
# 2021-05-23 22:44:03,092 - 01_eval.py - INFO - CALC SCORE
# 2021-05-23 22:44:03,093 - 01_eval.py - INFO - ToyTrain
#                AUC      pAUC
# Source_0  0.738900  0.580000
# Source_1  0.729300  0.545789
# Source_2  0.742900  0.473684
# Target_0  0.755100  0.674737
# Target_1  0.587000  0.502105
# Target_2  0.771100  0.612105
# mean      0.720717  0.564737
# h_mean    0.714680  0.556853
# 2021-05-23 22:44:16,554 - 01_eval.py - INFO - CALC SCORE
# 2021-05-23 22:44:16,555 - 01_eval.py - INFO - valve
#                AUC      pAUC
# Source_0  0.579900  0.504737
# Source_1  0.536800  0.496842
# Source_2  0.636900  0.504211
# Target_0  0.509900  0.515263
# Target_1  0.783300  0.674211
# Target_2  0.508000  0.500000
# mean      0.592467  0.532544
# h_mean    0.578941  0.526260

# %% [markdown]
# for machine_type in machine_types:
#     # get MVG
#     mean = MVG[machine_type]['mean']
#     cov_inv = np.linalg.inv(MVG[machine_type]['cov'])
#     # load data
#     ext_data = load_ext_data(machine_type)
#     # calc mahalanobis (Anomaly Score)
#     valid_source_dists = [mahalanobis(sample, mean, cov_inv) for sample in ext_data['valid_source']['features']]
#     valid_target_dists = [mahalanobis(sample, mean, cov_inv) for sample in ext_data['valid_target']['features']]
#     # np.array
#     valid_source_dists = np.array(valid_source_dists)
#     valid_target_dists = np.array(valid_target_dists)
#     # calc AUC
#     roc_auc = roc_auc_score(ext_data['valid_source']['labels'], valid_source_dists)
#     logger.info(f'{machine_type} valid_source AUC : {roc_auc}')
#     roc_auc = roc_auc_score(ext_data['valid_target']['labels'], valid_target_dists)
#     logger.info(f'{machine_type} valid_target AUC : {roc_auc}')
#
#     plt.figure(figsize=(20,3))
#     plt.title(f'Source {machine_type}')
#     plt.plot(valid_source_dists, label='Anomaly Score')
#     plt.plot(ext_data['valid_source']['labels'], label='Ground Truth')
#     plt.legend()
#     plt.show()
#
#     plt.figure(figsize=(20,3))
#     plt.title(f'Target {machine_type}')
#     plt.plot(valid_target_dists, label='Anomaly Score')
#     plt.plot(ext_data['valid_target']['labels'], label='Ground Truth')
#     plt.legend()
#     plt.show()
